# %% [markdown]
# Question 1: Load a CSV file containing a dataset into a Pandas DataFrame. Display the first few rows to understand its basic structure.

# %%
import pandas as pd

# Load the CSV file into a Pandas DataFrame
# Replace 'your_dataset.csv' with the actual path to your CSV file
df = pd.read_csv('your_dataset.csv')

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# Question 2: Determine the number of rows and columns in the dataset.

# %%
# Write your code from here
import pandas as pd

# Assuming your DataFrame is already loaded and named 'df' from Question 1
# df = pd.read_csv('your_dataset.csv') # Uncomment this line if you're running this independently

# Get the number of rows and columns
num_rows, num_columns = df.shape

print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_columns}")
# Out:
# Number of rows: 20
# Number of columns: 6

# %% [markdown]
# Question 3: Identify the data type of each column in the dataset.

# %%
import pandas as pd

# Load the CSV file into a Pandas DataFrame
# Make sure 'your_dataset.csv' is in the same directory as your script,
# or provide the full path to the file.
try:
    df = pd.read_csv('your_dataset.csv')
except FileNotFoundError:
    print("Error: 'your_dataset.csv' not found. Please make sure the file is in the correct directory.")
    print("Creating a sample DataFrame for demonstration purposes.")
    # Create a sample DataFrame if the file isn't found
    import numpy as np
    data = {
        'Numerical_Col_1': np.random.rand(10) * 100,
        'Numerical_Col_2': np.random.randint(1, 100, 10),
        'Categorical_Col_A': ['X', 'Y', 'X', 'Z', 'Y', 'X', 'Z', 'Y', 'X', 'Z'],
        'Categorical_Col_B': ['Red', 'Blue', 'Green', 'Red', 'Blue', 'Green', 'Red', 'Blue', 'Green', 'Red']
    }
    df = pd.DataFrame(data)

print("---")
print("First few rows of the dataset:")
print(df.head())

print("\n---")
print("Number of rows and columns:")
num_rows, num_columns = df.shape
print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_columns}")

print("\n---")
print("Data types of each column:")
print(df.dtypes)

print("\n---")
print("Summary statistics for numerical columns:")
print(df.describe())
# Out:
# ---
# First few rows of the dataset:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
# ---
# Number of rows and columns:
# Number of rows: 20
# Number of columns: 6
#
# ---
# Data types of each column:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object
#
# ---
# Summary statistics for numerical columns:
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# ...

# %% [markdown]
# Question 4: Generate summary statistics for the numerical columns in the dataset.

# %%
# Write your code from here
import pandas as pd
import numpy as np

# --- Question 1: Load a CSV file and display the first few rows ---
# Replace 'your_dataset.csv' with the actual path to your CSV file.
# If the file is not found, a sample DataFrame will be created for demonstration.
try:
    df = pd.read_csv('your_dataset.csv')
    print("Successfully loaded 'your_dataset.csv'")
except FileNotFoundError:
    print("Error: 'your_dataset.csv' not found. Creating a sample DataFrame for demonstration.")
    # Create a sample DataFrame if the file isn't found
    data = {
        'ID': range(1, 11),
        'Numerical_Feature_A': np.random.rand(10) * 100,
        'Numerical_Feature_B': np.random.randint(10, 100, 10),
        'Categorical_Feature_C': np.random.choice(['Category_X', 'Category_Y', 'Category_Z'], 10),
        'Boolean_Feature_D': np.random.choice([True, False], 10)
    }
    df = pd.DataFrame(data)

print("\n--- First few rows of the dataset ---")
print(df.head())

# --- Question 2: Determine the number of rows and columns ---
num_rows, num_columns = df.shape
print(f"\n--- Dataset Dimensions ---")
print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_columns}")

# --- Question 3: Identify the data type of each column ---
print(f"\n--- Data Types of Each Column ---")
print(df.dtypes)

# --- Question 4: Generate summary statistics for the numerical columns ---
print(f"\n--- Summary Statistics for Numerical Columns ---")
print(df.describe())
# Out:
# Successfully loaded 'your_dataset.csv'
#
# --- First few rows of the dataset ---
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
# --- Dataset Dimensions ---
# Number of rows: 20
# Number of columns: 6
#
# --- Data Types of Each Column ---
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object
#
# --- Summary Statistics for Numerical Columns ---
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# ...

# %% [markdown]
# Question 5: Identify columns with missing values and count the number of missing values in each.

# %%
# Write your code from here
import pandas as pd
import numpy as np

# Create a sample DataFrame with missing values for demonstration
# (This part would be replaced by your actual df loaded from a CSV)
data = {
    'Feature1': [1, 2, np.nan, 4, 5],
    'Feature2': [10, 20, 30, np.nan, np.nan],
    'Feature3': ['A', 'B', 'C', 'D', 'E'],
    'Feature4': [np.nan, np.nan, np.nan, np.nan, np.nan],
    'Feature5': [100, 200, 300, 400, 500]
}
df = pd.DataFrame(data)

print("Original DataFrame:")
print(df)

# Identify columns with missing values and count them
missing_values_count = df.isnull().sum()

# Filter to show only columns that have missing values
columns_with_missing_values = missing_values_count[missing_values_count > 0]

print("\n--- Columns with Missing Values and their Counts ---")
if not columns_with_missing_values.empty:
    print(columns_with_missing_values)
else:
    print("No missing values found in any column.")
# Out:
# Original DataFrame:
#    Feature1  Feature2 Feature3  Feature4  Feature5
# 0       1.0      10.0        A       NaN       100
# 1       2.0      20.0        B       NaN       200
# 2       NaN      30.0        C       NaN       300
# 3       4.0       NaN        D       NaN       400
# 4       5.0       NaN        E       NaN       500
#
# --- Columns with Missing Values and their Counts ---
# Feature1    1
# Feature2    2
# Feature4    5
# dtype: int64

# %% [markdown]
# Question 6: Replace missing values in a column with the median value of that column.

# %%
# Write your code from here
import pandas as pd
import numpy as np

# Create a sample DataFrame with missing values for demonstration
data = {
    'ColumnA': [10, 20, np.nan, 40, 50],
    'ColumnB': [1, np.nan, 3, 4, np.nan],
    'ColumnC': ['apple', 'banana', 'cherry', np.nan, 'date']
}
df = pd.DataFrame(data)

print("Original DataFrame:")
print(df)

# Identify the column with missing values (e.g., 'ColumnA')
column_to_impute = 'ColumnA'

# Calculate the median of the specified column
# .median() automatically ignores NaN values
median_value = df[column_to_impute].median()

print(f"\nMedian of '{column_to_impute}': {median_value}")

# Replace missing values (NaN) in the column with its median
df[column_to_impute].fillna(median_value, inplace=True)

print(f"\nDataFrame after imputing missing values in '{column_to_impute}':")
print(df)

# You can repeat this process for other numerical columns as needed.
# For example, for 'ColumnB':
column_to_impute_B = 'ColumnB'
median_value_B = df[column_to_impute_B].median()
df[column_to_impute_B].fillna(median_value_B, inplace=True)

print(f"\nDataFrame after imputing missing values in '{column_to_impute_B}':")
print(df)
# Out:
# Original DataFrame:
#    ColumnA  ColumnB ColumnC
# 0     10.0      1.0   apple
# 1     20.0      NaN  banana
# 2      NaN      3.0  cherry
# 3     40.0      4.0     NaN
# 4     50.0      NaN    date
#
# Median of 'ColumnA': 30.0
#
# DataFrame after imputing missing values in 'ColumnA':
#    ColumnA  ColumnB ColumnC
# 0     10.0      1.0   apple
# 1     20.0      NaN  banana
# 2     30.0      3.0  cherry
# 3     40.0      4.0     NaN
# 4     50.0      NaN    date
#
# DataFrame after imputing missing values in 'ColumnB':
#    ColumnA  ColumnB ColumnC
# 0     10.0      1.0   apple
# 1     20.0      3.0  banana
# 2     30.0      3.0  cherry
# 3     40.0      4.0     NaN
# 4     50.0      3.0    date
# /tmp/ipykernel_23159/2707702848.py:26: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# Question 7: Remove duplicate rows from the dataset.

# %%
# Write your code from here
import pandas as pd
import numpy as np

# Create a sample DataFrame with some duplicate rows for demonstration
data = {
    'ColA': [1, 2, 3, 1, 4, 2, 5],
    'ColB': ['X', 'Y', 'Z', 'X', 'A', 'Y', 'B'],
    'ColC': [10, 20, 30, 10, 40, 20, 50]
}
df = pd.DataFrame(data)

print("Original DataFrame (with duplicates):")
print(df)

# Remove duplicate rows
# By default, keep='first' (keeps the first occurrence, removes subsequent duplicates)
# To modify the DataFrame in place, use inplace=True
df.drop_duplicates(inplace=True)

print("\nDataFrame after removing duplicate rows:")
print(df)

# If you wanted to keep the last occurrence, you would use:
# df.drop_duplicates(keep='last', inplace=True)

# If you wanted to remove all duplicates (even the first occurrence if there's a duplicate), you would use:
# df.drop_duplicates(keep=False, inplace=True)
# Out:
# Original DataFrame (with duplicates):
#    ColA ColB  ColC
# 0     1    X    10
# 1     2    Y    20
# 2     3    Z    30
# 3     1    X    10
# 4     4    A    40
# 5     2    Y    20
# 6     5    B    50
#
# DataFrame after removing duplicate rows:
#    ColA ColB  ColC
# 0     1    X    10
# 1     2    Y    20
# 2     3    Z    30
# 4     4    A    40
# 6     5    B    50

# %% [markdown]
# Question 8: Create a histogram to visualize the distribution of a numerical column (e.g., 'price').

# %%
# Write your code from here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns # Often used for enhanced visualizations

# Create a sample DataFrame with a numerical 'price' column for demonstration
# This part would be replaced by your actual df loaded from a CSV
np.random.seed(42) # For reproducibility
data = {
    'product_id': range(1, 101),
    'price': np.random.normal(loc=50, scale=15, size=100), # Normally distributed prices
    'category': np.random.choice(['Electronics', 'Books', 'Clothing', 'Home'], 100),
    'quantity': np.random.randint(1, 10, 100)
}
df = pd.DataFrame(data)

# Ensure 'price' column contains only positive values, as prices cannot be negative
df['price'] = df['price'].apply(lambda x: max(0, x))

print("First few rows of the DataFrame with 'price' column:")
print(df.head())

# --- Create a histogram to visualize the distribution of 'price' ---

# Method 1: Using Pandas built-in .hist() (uses Matplotlib internally)
plt.figure(figsize=(10, 6))
df['price'].hist(bins=15, edgecolor='black', grid=False) # bins control the number of bars
plt.title('Distribution of Product Prices (Pandas .hist())')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# Method 2: Using Seaborn (often preferred for aesthetics)
plt.figure(figsize=(10, 6))
sns.histplot(df['price'], bins=15, kde=True, edgecolor='black') # kde=True adds a kernel density estimate
plt.title('Distribution of Product Prices (Seaborn histplot)')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# Method 3: Using Matplotlib directly
plt.figure(figsize=(10, 6))
plt.hist(df['price'], bins=15, edgecolor='black', alpha=0.7)
plt.title('Distribution of Product Prices (Matplotlib hist)')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

print("\nHistogram successfully generated for the 'price' column.")
print("The histograms show the frequency of prices within different ranges.")
# Out:
# First few rows of the DataFrame with 'price' column:
#    product_id      price     category  quantity
# 0           1  57.450712  Electronics         9
# 1           2  47.926035        Books         9
# 2           3  59.715328  Electronics         2
# 3           4  72.845448  Electronics         7
# 4           5  46.487699     Clothing         3
# Histogram successfully generated for the 'price' column.
# The histograms show the frequency of prices within different ranges.

# %% [markdown]
# Question 9: Create a scatter plot to visualize the relationship between two numerical variables

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# --- Create a sample DataFrame if one doesn't exist ---
# This ensures the code is runnable even if you haven't loaded a CSV previously.
# In a real scenario, 'df' would be your loaded DataFrame.
try:
    # Attempt to use an existing 'df' if it was created in a previous cell/run
    if 'df' not in locals():
        raise NameError("df is not defined, creating a sample DataFrame.")
    # Check if 'df' has the required columns; if not, re-create.
    if 'price' not in df.columns or 'quantity_sold' not in df.columns:
        raise ValueError("Required columns 'price' or 'quantity_sold' not in existing DataFrame. Creating sample.")
except (NameError, ValueError):
    print("Creating a sample DataFrame for demonstration purposes.")
    np.random.seed(42) # For reproducibility
    data = {
        'product_id': range(1, 101),
        'price': np.random.normal(loc=50, scale=15, size=100),
        'quantity_sold': np.random.randint(1, 100, 100),
        'category': np.random.choice(['Electronics', 'Books', 'Clothing', 'Home'], 100)
    }
    df = pd.DataFrame(data)
    # Ensure 'price' is non-negative and 'quantity_sold' is positive for realistic data
    df['price'] = df['price'].apply(lambda x: max(0, x))
    df['quantity_sold'] = df['quantity_sold'].apply(lambda x: max(1, x))

print("First few rows of the DataFrame (with 'price' and 'quantity_sold' columns):")
print(df.head())

# --- Create a scatter plot ---
plt.figure(figsize=(10, 6))
# Using seaborn.scatterplot for enhanced aesthetics and readability.
# 'hue' can be used to color points based on a categorical variable (e.g., 'category').
sns.scatterplot(x='price', y='quantity_sold', data=df, hue='category', s=80, alpha=0.7)

plt.title('Relationship between Product Price and Quantity Sold')
plt.xlabel('Price')
plt.ylabel('Quantity Sold')
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(title='Category')
plt.tight_layout() # Adjust layout to prevent labels from overlapping
plt.show()

print("\n**Scatter plot successfully generated!**")
print("This visualization helps in understanding the pattern or correlation between the two numerical variables.")
print("For example, you can see if higher prices generally lead to lower quantities sold, or vice versa, or if there's no clear relationship.")
# Out:
# Creating a sample DataFrame for demonstration purposes.
# First few rows of the DataFrame (with 'price' and 'quantity_sold' columns):
#    product_id      price  quantity_sold  category
# 0           1  57.450712              9      Home
# 1           2  47.926035             62  Clothing
# 2           3  59.715328             37      Home
# 3           4  72.845448             97      Home
# 4           5  46.487699             51     Books
# **Scatter plot successfully generated!**
# This visualization helps in understanding the pattern or correlation between the two numerical variables.
# For example, you can see if higher prices generally lead to lower quantities sold, or vice versa, or if there's no clear relationship.

# %% [markdown]
# Question 10: Visualize the correlation matrix of the dataset using a heatmap.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# --- Configuration ---
# IMPORTANT: Replace 'your_dataset.csv' with the actual path to your CSV file.
# If the file is not found, a sample DataFrame will be created.
CSV_FILE_PATH = 'your_dataset.csv'

# Define column names for specific tasks (adjust if your dataset columns are different)
# Make sure these columns exist in your actual dataset or the sample data.
NUMERICAL_COLUMN_FOR_HISTOGRAM = 'price'
NUMERICAL_COL1_FOR_SCATTER = 'price'
NUMERICAL_COL2_FOR_SCATTER = 'quantity_sold'
# Ensure this column name exists in your dataset and is numerical
COLUMN_TO_IMPUTE_MEDIAN = 'Feature1'


# --- 1. Load the Dataset ---
print("--- 1. Loading Dataset ---")
try:
    df = pd.read_csv(CSV_FILE_PATH)
    print(f"Successfully loaded '{CSV_FILE_PATH}'")
except FileNotFoundError:
    print(f"Error: '{CSV_FILE_PATH}' not found. Creating a sample DataFrame for demonstration.")
    # Create a comprehensive sample DataFrame if the file isn't found
    np.random.seed(42) # for reproducibility

    # Ensure 'Feature1' is present in the sample data
    data = {
        'ID': range(1, 101),
        'Numerical_Col_A': np.random.rand(100) * 100,
        'Numerical_Col_B': np.random.randint(1, 100, 100),
        'Categorical_Col_C': np.random.choice(['Group1', 'Group2', 'Group3'], 100),
        'price': np.random.normal(loc=50, scale=15, size=100), # Used for histogram & scatter
        'quantity_sold': np.random.randint(1, 100, 100), # Used for scatter

        # Explicitly include 'Feature1' for imputation demonstration
        'Feature1': [10, 20, np.nan, 40, 50, 60, np.nan, 80, 90, 100] * 10, # For imputation demo
        'Feature2': [1, np.nan, 3, 4, np.nan] * 20, # Another column with NaNs
        'Feature3': ['alpha', 'beta', 'gamma', 'delta', 'epsilon'] * 20,
        'Feature4': [np.nan] * 100, # Fully missing column for demonstration
    }
    df = pd.DataFrame(data)
    # Introduce some duplicates for Task 8
    df = pd.concat([df, df.sample(5)], ignore_index=True)
    # Introduce more specific NaNs for other numerical/categorical columns
    df.loc[df.sample(frac=0.05).index, 'Numerical_Col_A'] = np.nan
    df.loc[df.sample(frac=0.03).index, 'Categorical_Col_C'] = np.nan


# Ensure numerical columns used for plotting are non-negative, if applicable
if NUMERICAL_COLUMN_FOR_HISTOGRAM in df.columns:
    df[NUMERICAL_COLUMN_FOR_HISTOGRAM] = df[NUMERICAL_COLUMN_FOR_HISTOGRAM].apply(lambda x: max(0, x))
if NUMERICAL_COL2_FOR_SCATTER in df.columns:
    df[NUMERICAL_COL2_FOR_SCATTER] = df[NUMERICAL_COL2_FOR_SCATTER].apply(lambda x: max(1, x)) # Quantities usually > 0

# --- 2. Display the First Few Rows ---
print("\n--- 2. First 5 Rows of the Dataset ---")
print(df.head())

# --- 3. Determine the Number of Rows and Columns ---
print("\n--- 3. Dataset Dimensions ---")
num_rows, num_columns = df.shape
print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_columns}")

# --- 4. Identify the Data Type of Each Column ---
print("\n--- 4. Data Types of Each Column ---")
print(df.dtypes)

# --- 5. Generate Summary Statistics for Numerical Columns ---
print("\n--- 5. Summary Statistics for Numerical Columns ---")
print(df.describe())

# --- 6. Identify Columns with Missing Values and Count Them ---
print("\n--- 6. Missing Values Identification ---")
missing_values_count = df.isnull().sum()
columns_with_missing_values = missing_values_count[missing_values_count > 0]

if not columns_with_missing_values.empty:
    print("Columns with Missing Values and their Counts:")
    print(columns_with_missing_values)
else:
    print("No missing values found in any column.")

# --- 7. Replace Missing Values in a Column with the Median ---
print(f"\n--- 7. Imputing Missing Values in '{COLUMN_TO_IMPUTE_MEDIAN}' ---")
if COLUMN_TO_IMPUTE_MEDIAN in df.columns and pd.api.types.is_numeric_dtype(df[COLUMN_TO_IMPUTE_MEDIAN]):
    initial_nan_count = df[COLUMN_TO_IMPUTE_MEDIAN].isnull().sum()
    if initial_nan_count > 0:
        median_value = df[COLUMN_TO_IMPUTE_MEDIAN].median()
        df[COLUMN_TO_IMPUTE_MEDIAN].fillna(median_value, inplace=True)
        print(f"Missing values in '{COLUMN_TO_IMPUTE_MEDIAN}' (initial count: {initial_nan_count}) replaced with median: {median_value}")
    else:
        print(f"No missing values to impute in '{COLUMN_TO_IMPUTE_MEDIAN}'.")
else:
    print(f"Column '{COLUMN_TO_IMPUTE_MEDIAN}' not found or is not numerical. Skipping imputation.")
# Display a few rows to confirm imputation, handling if column doesn't exist
if COLUMN_TO_IMPUTE_MEDIAN in df.columns:
    print(f"DataFrame head after potential imputation for '{COLUMN_TO_IMPUTE_MEDIAN}':")
    print(df[[COLUMN_TO_IMPUTE_MEDIAN]].head(7))
else:
    print(f"Cannot display head for '{COLUMN_TO_IMPUTE_MEDIAN}' as it's not in the DataFrame.")


# --- 8. Remove Duplicate Rows from the Dataset ---
print("\n--- 8. Removing Duplicate Rows ---")
initial_rows = df.shape[0]
df.drop_duplicates(inplace=True)
rows_after_dropping_duplicates = df.shape[0]
print(f"Initial number of rows: {initial_rows}")
print(f"Number of rows after removing duplicates: {rows_after_dropping_duplicates}")
print(f"Number of duplicate rows removed: {initial_rows - rows_after_dropping_duplicates}")
print("DataFrame head after removing duplicates:")
print(df.head())


# --- 9. Create a Histogram to Visualize the Distribution of a Numerical Column ---
print(f"\n--- 9. Creating Histogram for '{NUMERICAL_COLUMN_FOR_HISTOGRAM}' ---")
if NUMERICAL_COLUMN_FOR_HISTOGRAM in df.columns and pd.api.types.is_numeric_dtype(df[NUMERICAL_COLUMN_FOR_HISTOGRAM]):
    plt.figure(figsize=(10, 6))
    sns.histplot(df[NUMERICAL_COLUMN_FOR_HISTOGRAM], bins=15, kde=True, edgecolor='black')
    plt.title(f'Distribution of {NUMERICAL_COLUMN_FOR_HISTOGRAM.replace("_", " ").title()}')
    plt.xlabel(NUMERICAL_COLUMN_FOR_HISTOGRAM.replace("_", " ").title())
    plt.ylabel('Frequency')
    plt.grid(axis='y', alpha=0.75)
    plt.show()
    print(f"Histogram for '{NUMERICAL_COLUMN_FOR_HISTOGRAM}' generated.")
else:
    print(f"Column '{NUMERICAL_COLUMN_FOR_HISTOGRAM}' not found or is not numerical. Skipping histogram creation.")


# --- 10. Create a Scatter Plot to Visualize the Relationship Between Two Numerical Variables ---
print(f"\n--- 10. Creating Scatter Plot for '{NUMERICAL_COL1_FOR_SCATTER}' vs '{NUMERICAL_COL2_FOR_SCATTER}' ---")
if (NUMERICAL_COL1_FOR_SCATTER in df.columns and pd.api.types.is_numeric_dtype(df[NUMERICAL_COL1_FOR_SCATTER])) and \
   (NUMERICAL_COL2_FOR_SCATTER in df.columns and pd.api.types.is_numeric_dtype(df[NUMERICAL_COL2_FOR_SCATTER])):
    plt.figure(figsize=(10, 6))
    # Using 'Categorical_Col_C' for hue to show grouping, remove if not desired or applicable
    sns.scatterplot(x=NUMERICAL_COL1_FOR_SCATTER, y=NUMERICAL_COL2_FOR_SCATTER, data=df, hue='Categorical_Col_C', s=80, alpha=0.7)
    plt.title(f'Relationship between {NUMERICAL_COL1_FOR_SCATTER.replace("_", " ").title()} and {NUMERICAL_COL2_FOR_SCATTER.replace("_", " ").title()}')
    plt.xlabel(NUMERICAL_COL1_FOR_SCATTER.replace("_", " ").title())
    plt.ylabel(NUMERICAL_COL2_FOR_SCATTER.replace("_", " ").title())
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.show()
    print(f"Scatter plot for '{NUMERICAL_COL1_FOR_SCATTER}' and '{NUMERICAL_COL2_FOR_SCATTER}' generated.")
else:
    print(f"One or both columns ('{NUMERICAL_COL1_FOR_SCATTER}', '{NUMERICAL_COL2_FOR_SCATTER}') not found or are not numerical. Skipping scatter plot creation.")

# --- 11. Visualize the Correlation Matrix of the Dataset Using a Heatmap ---
print(f"\n--- 11. Visualizing Correlation Matrix using a Heatmap ---")

# Calculate the correlation matrix for numerical columns only
correlation_matrix = df.corr(numeric_only=True)

if not correlation_matrix.empty:
    print("\nCorrelation Matrix:")
    print(correlation_matrix)

    # Visualize the correlation matrix using a heatmap
    plt.figure(figsize=(10, 8))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
    plt.title('Correlation Matrix of Numerical Columns')
    plt.show()
    print("\nHeatmap of the correlation matrix successfully generated.")
    print("Values close to 1 or -1 indicate a strong positive or negative linear relationship.")
    print("Values close to 0 indicate a weak or no linear relationship.")
else:
    print("No numerical columns found to calculate a correlation matrix.")
# Out:
# --- 1. Loading Dataset ---
# Successfully loaded 'your_dataset.csv'
#
# --- 2. First 5 Rows of the Dataset ---
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
# --- 3. Dataset Dimensions ---
# Number of rows: 20
# Number of columns: 6
#
# --- 4. Data Types of Each Column ---
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object
#
# --- 5. Summary Statistics for Numerical Columns ---
# ...
